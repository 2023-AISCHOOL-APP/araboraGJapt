# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.font_manager as fm

# %%
font_path = r'C:\Windows\Fonts\gulim.ttf'
plt.rc('font', family='Gulim')

# %%
data=pd.read_csv('../2~3.데이터 수집 및 전처리/머신러닝 전처리 데이터.CSV',encoding="EUC-KR")

# %%
data=data.drop(['Unnamed: 0','계약일'],axis=1)

# %%
data
# Out:
#                   시군구      단지명   전용면적(㎡)    계약년월        계약날짜   층  건축나이  거래건수  \
# 0       광주광역시 광산구 도산동      대덕1   59.3100  202303  2023-03-18   4    33    20
# 1       광주광역시 광산구 도산동  대주피오레1차   84.9800  202302  2023-02-07   2    23    14
# 2       광주광역시 광산구 도산동  대주피오레1차   84.9800  202305  2023-05-31   5    23    16
# 3       광주광역시 광산구 도산동  대주피오레2차   84.7575  202305  2023-05-09   5    22    16
# 4       광주광역시 광산구 도산동  대주피오레2차   84.7575  202305  2023-05-13  13    22    16
# ...               ...      ...       ...     ...         ...  ..   ...   ...
# 425074   광주광역시 서구 화정동     화정우미  115.1850  200611  2006-11-10  17    10   131
# 425075   광주광역시 서구 화정동     화정우미   84.8300  200611  2006-11-27   6    10   131
# 425076   광주광역시 서구 화정동     화정우미   59.8300  200611  2006-11-30   2    10   131
# 425077   광주광역시 서구 화정동     화정우미   84.8400  200612  2006-12-06  16    10   124
# 425078   광주광역시 서구 화정동     화정우미  115.1850  200612  2006-12-12  14    10   124
#
#         기준금리       법정동코드  지하철역수  거래금액(만원)
# 0        3.5  2920010200      1      9800
# 1        3.5  2920010200      1     21000
# 2        3.5  2920010200      1     22350
# 3        3.5  2920010200      1     22400
# 4        3.5  2920010200      1     22000
# ...      ...         ...    ...       ...
# 425074   4.5  2914011900      1     19000
# 425075   4.5  2914011900      1     12000
# 425076   4.5  2914011900      1      7700
# 425077   4.5  2914011900      1     12170
# 425078   4.5  2914011900      1     17500
#
# [425079 rows x 12 columns]
