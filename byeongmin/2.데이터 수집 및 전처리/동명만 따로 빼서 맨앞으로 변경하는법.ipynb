# %%
import pandas as pd

# %%
data= pd.read_csv('06~23 광주아파트(매매).CSV', encoding = "EUC-KR")
# Out:
# C:\Users\gjaischool1\AppData\Local\Temp\ipykernel_24520\1377698204.py:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data= pd.read_csv('06~23 광주아파트(매매).CSV', encoding = "EUC-KR")

# %%
data.head(5)
# Out:
#              시군구      번지    본번  부번      단지명  단지명길이  전용면적(㎡)    계약년월   계약년  \
# 0  광주광역시 광산구 도산동  1138-2  1138   2      대덕1      3  59.3100  202303  2023
# 1  광주광역시 광산구 도산동     790   790   0  대주피오레1차      7  84.9800  202302  2023
# 2  광주광역시 광산구 도산동     790   790   0  대주피오레1차      7  84.9800  202305  2023
# 3  광주광역시 광산구 도산동     820   820   0  대주피오레2차      7  84.7575  202305  2023
# 4  광주광역시 광산구 도산동     820   820   0  대주피오레2차      7  84.7575  202305  2023
#
#    계약월  계약일 거래금액(만원)   층  건축년도            도로명  해제사유발생일  거래유형  중개사소재지
# 0    3   18    9,800   4  1990        송도로 143      NaN  중개거래  광주 광산구
# 1    2    7   21,000   2  2000    송도로182번길 55      NaN  중개거래  광주 광산구
# 2    5   31   22,350   5  2000    송도로182번길 55      NaN  중개거래  광주 광산구
# 3    5    9   22,400   5  2001  송도로182번길 16-3      NaN   직거래       -
# 4    5   13   22,000  13  2001  송도로182번길 16-3      NaN  중개거래  광주 광산구

# %%
data['동명'] = data['시군구'].apply(lambda x: x.split()[-1])

# %%
data.head(5)
# Out:
#              시군구      번지    본번  부번      단지명  단지명길이  전용면적(㎡)    계약년월   계약년  \
# 0  광주광역시 광산구 도산동  1138-2  1138   2      대덕1      3  59.3100  202303  2023
# 1  광주광역시 광산구 도산동     790   790   0  대주피오레1차      7  84.9800  202302  2023
# 2  광주광역시 광산구 도산동     790   790   0  대주피오레1차      7  84.9800  202305  2023
# 3  광주광역시 광산구 도산동     820   820   0  대주피오레2차      7  84.7575  202305  2023
# 4  광주광역시 광산구 도산동     820   820   0  대주피오레2차      7  84.7575  202305  2023
#
#    계약월  계약일 거래금액(만원)   층  건축년도            도로명  해제사유발생일  거래유형  중개사소재지   동명
# 0    3   18    9,800   4  1990        송도로 143      NaN  중개거래  광주 광산구  도산동
# 1    2    7   21,000   2  2000    송도로182번길 55      NaN  중개거래  광주 광산구  도산동
# 2    5   31   22,350   5  2000    송도로182번길 55      NaN  중개거래  광주 광산구  도산동
# 3    5    9   22,400   5  2001  송도로182번길 16-3      NaN   직거래       -  도산동
# 4    5   13   22,000  13  2001  송도로182번길 16-3      NaN  중개거래  광주 광산구  도산동

# %%
dong=data.pop('동명')

# %%
data.insert(0,'동명',dong)

# %%
data
# Out:
#          동명            시군구      번지    본번  부번      단지명  단지명길이   전용면적(㎡)  \
# 0       도산동  광주광역시 광산구 도산동  1138-2  1138   2      대덕1      3   59.3100
# 1       도산동  광주광역시 광산구 도산동     790   790   0  대주피오레1차      7   84.9800
# 2       도산동  광주광역시 광산구 도산동     790   790   0  대주피오레1차      7   84.9800
# 3       도산동  광주광역시 광산구 도산동     820   820   0  대주피오레2차      7   84.7575
# 4       도산동  광주광역시 광산구 도산동     820   820   0  대주피오레2차      7   84.7575
# ...     ...            ...     ...   ...  ..      ...    ...       ...
# 425074  화정동   광주광역시 서구 화정동     440   440   0     화정우미      4  115.1850
# 425075  화정동   광주광역시 서구 화정동     440   440   0     화정우미      4   84.8300
# 425076  화정동   광주광역시 서구 화정동     440   440   0     화정우미      4   59.8300
# 425077  화정동   광주광역시 서구 화정동     440   440   0     화정우미      4   84.8400
# 425078  화정동   광주광역시 서구 화정동     440   440   0     화정우미      4  115.1850
#
#           계약년월   계약년  계약월  계약일 거래금액(만원)   층  건축년도            도로명  해제사유발생일  \
# 0       202303  2023    3   18    9,800   4  1990        송도로 143      NaN
# 1       202302  2023    2    7   21,000   2  2000    송도로182번길 55      NaN
# 2       202305  2023    5   31   22,350   5  2000    송도로182번길 55      NaN
# 3       202305  2023    5    9   22,400   5  2001  송도로182번길 16-3      NaN
# 4       202305  2023    5   13   22,000  13  2001  송도로182번길 16-3      NaN
# ...        ...   ...  ...  ...      ...  ..   ...            ...      ...
# 425074  200611  2006   11   10   19,000  17  1996     염화로31번길 23      NaN
# 425075  200611  2006   11   27   12,000   6  1996     염화로31번길 23      NaN
# 425076  200611  2006   11   30    7,700   2  1996     염화로31번길 23      NaN
# 425077  200612  2006   12    6   12,170  16  1996     염화로31번길 23      NaN
# 425078  200612  2006   12   12   17,500  14  1996     염화로31번길 23      NaN
#
#         거래유형  중개사소재지
# 0       중개거래  광주 광산구
# 1       중개거래  광주 광산구
# 2       중개거래  광주 광산구
# 3        직거래       -
# 4       중개거래  광주 광산구
# ...      ...     ...
# 425074   NaN     NaN
# 425075   NaN     NaN
# 425076   NaN     NaN
# 425077   NaN     NaN
# 425078   NaN     NaN
#
# [425079 rows x 19 columns]
