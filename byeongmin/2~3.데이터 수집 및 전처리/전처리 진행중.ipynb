# %%
import pandas as pd

# %%
data= pd.read_csv("06~23 광주아파트(매매).csv", encoding="EUC-KR")
# Out:
# C:\Users\gjaischool1\AppData\Local\Temp\ipykernel_14772\3144801100.py:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data= pd.read_csv("06~23 광주아파트(매매).csv", encoding="EUC-KR")

# %%
data.head()
# Out:
#              시군구      번지    본번  부번      단지명  단지명길이  전용면적(㎡)    계약년월   계약년  \
# 0  광주광역시 광산구 도산동  1138-2  1138   2      대덕1      3  59.3100  202303  2023
# 1  광주광역시 광산구 도산동     790   790   0  대주피오레1차      7  84.9800  202302  2023
# 2  광주광역시 광산구 도산동     790   790   0  대주피오레1차      7  84.9800  202305  2023
# 3  광주광역시 광산구 도산동     820   820   0  대주피오레2차      7  84.7575  202305  2023
# 4  광주광역시 광산구 도산동     820   820   0  대주피오레2차      7  84.7575  202305  2023
#
#    계약월  계약일 거래금액(만원)   층  건축년도            도로명  해제사유발생일  거래유형  중개사소재지
# 0    3   18    9,800   4  1990        송도로 143      NaN  중개거래  광주 광산구
# 1    2    7   21,000   2  2000    송도로182번길 55      NaN  중개거래  광주 광산구
# 2    5   31   22,350   5  2000    송도로182번길 55      NaN  중개거래  광주 광산구
# 3    5    9   22,400   5  2001  송도로182번길 16-3      NaN   직거래       -
# 4    5   13   22,000  13  2001  송도로182번길 16-3      NaN  중개거래  광주 광산구

# %%
data=data.drop(['번지','본번','부번','단지명길이','계약월','도로명','해제사유발생일','거래유형','중개사소재지'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425079 entries, 0 to 425078
# Data columns (total 13 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   시군구       425079 non-null  object
#  1   단지명       425079 non-null  object
#  2   전용면적(㎡)   425079 non-null  float64
#  3   계약년월      425079 non-null  int64
#  4   계약일       425079 non-null  int64
#  5   계약날짜      425079 non-null  datetime64[ns]
#  6   층         425079 non-null  int64
#  7   건축나이      425079 non-null  int64
#  8   거래건수      425079 non-null  int64
#  9   기준금리      425079 non-null  float64
#  10  법정동코드     425079 non-null  int64
#  11  지하철역수     425079 non-null  int32
#  12  거래금액(만원)  425079 non-null  object
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(6), object(3)
# memory usage: 40.5+ MB

# %%
# 시군구에서 동명만 추출
data['동명'] = data['시군구'].apply(lambda x: x.split()[-1])

# %%
# 거래건수 추가
data['거래건수'] = data.groupby(['시군구', '계약년월'])['시군구'].transform('count')

# %%
# 건축나이 추가
data['건축나이']= data['계약년']-data['건축년도']

# %%
# 금리 추가
df_ir = pd.read_csv('한국은행 기준금리 및 여수신금리_2006~2023.csv')
df_ir['변환'].replace('/', '', regex=True, inplace=True)
df_ir['변환'] = df_ir['변환'].astype('int')
df_ir.set_index('변환', inplace=True)
data['기준금리'] = data['계약년월'].apply(lambda x: df_ir.loc[x, :][0])

# %%
data.head()
# Out:
#              시군구      단지명  전용면적(㎡)    계약년월   계약년  계약일 거래금액(만원)   층  건축년도   동명  \
# 0  광주광역시 광산구 도산동      대덕1  59.3100  202303  2023   18    9,800   4  1990  도산동
# 1  광주광역시 광산구 도산동  대주피오레1차  84.9800  202302  2023    7   21,000   2  2000  도산동
# 2  광주광역시 광산구 도산동  대주피오레1차  84.9800  202305  2023   31   22,350   5  2000  도산동
# 3  광주광역시 광산구 도산동  대주피오레2차  84.7575  202305  2023    9   22,400   5  2001  도산동
# 4  광주광역시 광산구 도산동  대주피오레2차  84.7575  202305  2023   13   22,000  13  2001  도산동
#
#    거래건수  건축나이  기준금리
# 0    20    33   3.5
# 1    14    23   3.5
# 2    16    23   3.5
# 3    16    22   3.5
# 4    16    22   3.5

# %%
# 법정명 코드 추가
bub_code=pd.read_csv('법정동코드 조회자료.csv')

# %%
bub_code
# Out:
#           법정동코드            법정동명
# 0    2900000000           광주광역시
# 1    2911000000        광주광역시 동구
# 2    2911010100    광주광역시 동구 대인동
# 3    2911010200  광주광역시 동구 금남로5가
# 4    2911010300  광주광역시 동구 충장로5가
# ..          ...             ...
# 203  2920017500   광주광역시 광산구 동호동
# 204  2920017600   광주광역시 광산구 덕림동
# 205  2920017700   광주광역시 광산구 양산동
# 206  2920017800   광주광역시 광산구 동림동
# 207  2920020200   광주광역시 광산구 오선동
#
# [208 rows x 2 columns]

# %%
data['법정동명']=data['시군구']

# %%
data = data.merge(bub_code, on='법정동명', how='left')

# %%
data
# Out:
#                   시군구      단지명   전용면적(㎡)    계약년월   계약년  계약일 거래금액(만원)   층  \
# 0       광주광역시 광산구 도산동      대덕1   59.3100  202303  2023   18    9,800   4
# 1       광주광역시 광산구 도산동  대주피오레1차   84.9800  202302  2023    7   21,000   2
# 2       광주광역시 광산구 도산동  대주피오레1차   84.9800  202305  2023   31   22,350   5
# 3       광주광역시 광산구 도산동  대주피오레2차   84.7575  202305  2023    9   22,400   5
# 4       광주광역시 광산구 도산동  대주피오레2차   84.7575  202305  2023   13   22,000  13
# ...               ...      ...       ...     ...   ...  ...      ...  ..
# 425074   광주광역시 서구 화정동     화정우미  115.1850  200611  2006   10   19,000  17
# 425075   광주광역시 서구 화정동     화정우미   84.8300  200611  2006   27   12,000   6
# 425076   광주광역시 서구 화정동     화정우미   59.8300  200611  2006   30    7,700   2
# 425077   광주광역시 서구 화정동     화정우미   84.8400  200612  2006    6   12,170  16
# 425078   광주광역시 서구 화정동     화정우미  115.1850  200612  2006   12   17,500  14
#
#         건축년도   동명  거래건수  건축나이  기준금리           법정동명       법정동코드
# 0       1990  도산동    20    33   3.5  광주광역시 광산구 도산동  2920010200
# 1       2000  도산동    14    23   3.5  광주광역시 광산구 도산동  2920010200
# 2       2000  도산동    16    23   3.5  광주광역시 광산구 도산동  2920010200
# 3       2001  도산동    16    22   3.5  광주광역시 광산구 도산동  2920010200
# 4       2001  도산동    16    22   3.5  광주광역시 광산구 도산동  2920010200
# ...      ...  ...   ...   ...   ...            ...         ...
# 425074  1996  화정동   131    10   4.5   광주광역시 서구 화정동  2914011900
# 425075  1996  화정동   131    10   4.5   광주광역시 서구 화정동  2914011900
# 425076  1996  화정동   131    10   4.5   광주광역시 서구 화정동  2914011900
# 425077  1996  화정동   124    10   4.5   광주광역시 서구 화정동  2914011900
# 425078  1996  화정동   124    10   4.5   광주광역시 서구 화정동  2914011900
#
# [425079 rows x 15 columns]

# %%
data=data.drop(['법정동명'],axis=1)

# %%
data=data.drop(['건축년도','동명'],axis=1)

# %%
data
# Out:
#                   시군구      단지명   전용면적(㎡)    계약년월  계약일   층  건축나이  거래건수  기준금리  \
# 0       광주광역시 광산구 도산동      대덕1   59.3100  202303   18   4    33    20   3.5
# 1       광주광역시 광산구 도산동  대주피오레1차   84.9800  202302    7   2    23    14   3.5
# 2       광주광역시 광산구 도산동  대주피오레1차   84.9800  202305   31   5    23    16   3.5
# 3       광주광역시 광산구 도산동  대주피오레2차   84.7575  202305    9   5    22    16   3.5
# 4       광주광역시 광산구 도산동  대주피오레2차   84.7575  202305   13  13    22    16   3.5
# ...               ...      ...       ...     ...  ...  ..   ...   ...   ...
# 425074   광주광역시 서구 화정동     화정우미  115.1850  200611   10  17    10   131   4.5
# 425075   광주광역시 서구 화정동     화정우미   84.8300  200611   27   6    10   131   4.5
# 425076   광주광역시 서구 화정동     화정우미   59.8300  200611   30   2    10   131   4.5
# 425077   광주광역시 서구 화정동     화정우미   84.8400  200612    6  16    10   124   4.5
# 425078   광주광역시 서구 화정동     화정우미  115.1850  200612   12  14    10   124   4.5
#
#              법정동코드  지하철역수 거래금액(만원)
# 0       2920010200      1    9,800
# 1       2920010200      1   21,000
# 2       2920010200      1   22,350
# 3       2920010200      1   22,400
# 4       2920010200      1   22,000
# ...            ...    ...      ...
# 425074  2914011900      1   19,000
# 425075  2914011900      1   12,000
# 425076  2914011900      1    7,700
# 425077  2914011900      1   12,170
# 425078  2914011900      1   17,500
#
# [425079 rows x 12 columns]

# %%
# 동별 지하철 갯수 추가
subway_count_data=pd.read_csv('동별 역갯수.csv', encoding="EUC-KR")

# %%
subway_count_data
# Out:
#        동명  지하철역수
# 0     광산동      1
# 1   금남로4가      1
# 2   금남로5가      1
# 3     농성동      2
# 4     도산동      1
# 5     마륵동      2
# 6     소태동      1
# 7     송정동      2
# 8     신촌동      1
# 9     쌍촌동      2
# 10     양동      1
# 11    용산동      1
# 12    월전동      1
# 13     학동      2
# 14    화정동      1

# %%
data=data.merge(subway_count_data, on="동명",how='left' )

# %%
data['지하철역수'].fillna(0, inplace=True)

# %%
data['지하철역수']
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 425074    1.0
# 425075    1.0
# 425076    1.0
# 425077    1.0
# 425078    1.0
# Name: 지하철역수, Length: 425079, dtype: float64

# %%
data['지하철역수'] = data['지하철역수'].astype(int)

# %%
column_order = ['시군구', '단지명', '전용면적(㎡)', '계약년월', '계약년', '계약일','계약날짜', '층', '건축나이', '거래건수', '기준금리', '법정동코드', '동명', '지하철역수', '거래금액(만원)']
data =data.reindex(columns=column_order)

# %%
data=data.drop(['계약년','동명'], axis=1)

# %%
data['계약날짜'] = pd.to_datetime(data['계약년월'].astype(str) + data['계약일'].astype(str), format='%Y%m%d')

# %%
data
# Out:
#                   시군구      단지명   전용면적(㎡)    계약년월  계약일       계약날짜   층  건축나이  \
# 0       광주광역시 광산구 도산동      대덕1   59.3100  202303   18 2023-03-18   4    33
# 1       광주광역시 광산구 도산동  대주피오레1차   84.9800  202302    7 2023-02-07   2    23
# 2       광주광역시 광산구 도산동  대주피오레1차   84.9800  202305   31 2023-05-31   5    23
# 3       광주광역시 광산구 도산동  대주피오레2차   84.7575  202305    9 2023-05-09   5    22
# 4       광주광역시 광산구 도산동  대주피오레2차   84.7575  202305   13 2023-05-13  13    22
# ...               ...      ...       ...     ...  ...        ...  ..   ...
# 425074   광주광역시 서구 화정동     화정우미  115.1850  200611   10 2006-11-10  17    10
# 425075   광주광역시 서구 화정동     화정우미   84.8300  200611   27 2006-11-27   6    10
# 425076   광주광역시 서구 화정동     화정우미   59.8300  200611   30 2006-11-30   2    10
# 425077   광주광역시 서구 화정동     화정우미   84.8400  200612    6 2006-12-06  16    10
# 425078   광주광역시 서구 화정동     화정우미  115.1850  200612   12 2006-12-12  14    10
#
#         거래건수  기준금리       법정동코드  지하철역수 거래금액(만원)
# 0         20   3.5  2920010200      1    9,800
# 1         14   3.5  2920010200      1   21,000
# 2         16   3.5  2920010200      1   22,350
# 3         16   3.5  2920010200      1   22,400
# 4         16   3.5  2920010200      1   22,000
# ...      ...   ...         ...    ...      ...
# 425074   131   4.5  2914011900      1   19,000
# 425075   131   4.5  2914011900      1   12,000
# 425076   131   4.5  2914011900      1    7,700
# 425077   124   4.5  2914011900      1   12,170
# 425078   124   4.5  2914011900      1   17,500
#
# [425079 rows x 13 columns]

# %%
data.to_csv('머신러닝 전처리 데이터.csv', encoding='EUC-KR')
